# %% [markdown]
# # Chapter 4 - Real-World Data Representation using Tensors
#
# ## Part II: 3D Images: Volumetric Data

# %% [markdown]
# Shape: [Batch, Channels, Depth, Height, Width]

# %%
import numpy as np
import torch
torch.set_printoptions(edgeitems=2, threshold=50)

# %%
import imageio

dir_path = '/Users/dongdongdongdong/Desktop/Deep-Learning-with-PyTorch/Datasets/Chapter 4/volumetric-dicom/2-LUNG 3.0  B70f-04083'
vol_arr = imageio.volread(dir_path, 'DICOM')
vol_arr.shape
# Out:
# Reading DICOM (examining files): 1/99 files (1.0%89/99 files (89.9%99/99 files (100.0%)
#   Found 1 correct series.
# Reading DICOM (loading data): 52/99  (52.599/99  (100.0%)
# (99, 512, 512)

# %%
vol = torch.from_numpy(vol_arr).float()
vol = torch.unsqueeze(vol, 0)
vol.shape
# Out:
# torch.Size([1, 99, 512, 512])

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

plt.imshow(vol_arr[50])
